# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # !unzip '/content/drive/MyDrive/70:30_Datasets/Road_Datasets.zip'
# Out:
# Archive:  /content/drive/MyDrive/70:30_Datasets/Road_Datasets.zip
#    creating: Road_Datasets/
#    creating: Road_Datasets/1/
#  extracting: Road_Datasets/1/1089_b.png
#  extracting: Road_Datasets/1/1096_b.png
#  extracting: Road_Datasets/1/1109_b.png
#  extracting: Road_Datasets/1/1120_b.png
#  extracting: Road_Datasets/1/1121_b.png
#  extracting: Road_Datasets/1/1147_b.png
#  extracting: Road_Datasets/1/1149_b.png
#  extracting: Road_Datasets/1/1155_b.png
#  extracting: Road_Datasets/1/1158_b.png
#  extracting: Road_Datasets/1/1214_b.png
#  extracting: Road_Datasets/1/1220_b.png
#  extracting: Road_Datasets/1/1260_b.png
#  extracting: Road_Datasets/1/1306_b.png
#  extracting: Road_Datasets/1/1357_b.png
#  extracting: Road_Datasets/1/1361_b.png
#  extracting: Road_Datasets/1/1370_b.png
#  extracting: Road_Datasets/1/1380_b.png
#  extracting: Road_Datasets/1/1383_b.png
#  extracting: Road_Datasets/1/1407_b.png
#  extracting: Road_Datasets/1/1413_b.png
# ...

# %%
import os

directory = r'/content/Road_Datasets/5'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        print(os.path.join(directory, filename))
    else:
        continue
# Out:
# /content/Road_Datasets/5/5575_v.png
# /content/Road_Datasets/5/5519_v.png
# /content/Road_Datasets/5/5799_v.png
# /content/Road_Datasets/5/5230_v.png
# /content/Road_Datasets/5/5346_v.png
# /content/Road_Datasets/5/6016_v.png
# /content/Road_Datasets/5/5467_v.png
# /content/Road_Datasets/5/5989_v.png
# /content/Road_Datasets/5/6014_v.png
# /content/Road_Datasets/5/5106_v.png
# /content/Road_Datasets/5/5662_v.png
# /content/Road_Datasets/5/5208_v.png
# /content/Road_Datasets/5/5839_v.png
# /content/Road_Datasets/5/5254_v.png
# /content/Road_Datasets/5/5052_v.png
# /content/Road_Datasets/5/1100_v.png
# /content/Road_Datasets/5/5449_v.png
# /content/Road_Datasets/5/5684_v.png
# /content/Road_Datasets/5/5721_v.png
# /content/Road_Datasets/5/5354_v.png
# /content/Road_Datasets/5/5693_v.png
# /content/Road_Datasets/5/5621_v.png
# /content/Road_Datasets/5/5966_v.png
# /content/Road_Datasets/5/5809_v.png
# /content/Road_Datasets/5/5938_v.png
# /content/Road_Datasets/5/5901_v.png
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import os

datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.2,
        zoom_range=0.2,
        brightness_range=[0.2,1.0],
        horizontal_flip=True,
        fill_mode='nearest')

for k in range(1,6):
  count=0
  directory = r'/content/Road_Datasets/'+str(k)
  for filename in os.listdir(directory):
      if filename.endswith(".png"):
          img = load_img(os.path.join(directory, filename))  # this is a PIL image
          x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
          x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)
          count+=1
          # the .flow() command below generates batches of randomly transformed images
          # and saves the results to the `preview/` directory
          i = 0
          for batch in datagen.flow(x, batch_size=1,save_to_dir='/content/drive/MyDrive/70:30_Datasets/70:30_train_test/'+str(k), save_prefix=str(count), save_format='png'):
              i += 1
              if i == 7:
                  break  # otherwise the generator would loop indefinitely
      else:
          continue
print(k)
# Out:
# 5

# %%
imagepath='/content/charandDig2/train/1'

# %%
import os

directory = r'/content/drive/MyDrive/70:30_Datasets/70:30_train_test/5'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        print(os.path.join(directory, filename))
    else:
        continue
# Out:
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_4308.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_980.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_9255.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_7107.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_4159.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_9928.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/1_0_5468.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/2_0_1780.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/2_0_1066.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/2_0_523.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/2_0_9853.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/2_0_3262.png
# /content/drive/MyDrive/70:30_Datasets/70:30_train_test/5/2_0_7937.png
# ...

# %% [markdown]
# Road Dataset zip\\
# extract\\
# create a folder X\\
# cretae 5 sub folder in folder X\\
# Then run\\
